# %%
import numpy as np
import pandas as pd
from scipy.spatial.distance import pdist, squareform

# Define station names and coordinates as provided
stations = {
    "Hoogvliet-Leemkuil": (51.867411, 4.355242),
    "Rotterdam Zuid-Pleinweg": (51.891147, 4.48069),
    "Rotterdam Zuid-Zwartewaalstraat": (51.893617, 4.487528),
    "Ridderkerk-Hogeweg": (51.869431, 4.580058),
    "Rotterdam-Oost Sidelinge A13": (51.938472, 4.430692),
    "Rotterdam Noord -Statenweg": (51.927111, 4.461344),
    "Schiedam-Alphons Arienstraat": (51.921389, 4.401389),
    "Maassluis-Kwartellaan": (51.932039, 4.228025),
    "Hoek v. Holland-Berghaven": (51.977803, 4.121944),
    "Alblasserdam-De Helling": (51.8579, 4.66012),
    "Posterholt-Vlodropperweg": (51.119194, 6.042399),
    "Vredepeel-Vredeweg": (51.54052, 5.85307),
    "Wijnandsrade-Opfergeltstraat": (50.902281, 5.881748),
    "Heerlen-Looierstraat": (50.887959, 5.970496),
    "Heerlen-Jamboreepad": (50.900317, 5.986853),
    "Biest Houtakker-Biestsestraat": (51.51844, 5.14845),
    "Huijbergen-Vennekenstraat": (51.434443, 4.359835),
    "Eindhoven-Genovevalaan": (51.468662, 5.47235),
    "Eindhoven-Noordbrabantlaan": (51.444157, 5.444833),
    "Breda-Tilburgseweg": (51.593533, 4.824944),
    "Breda-Bastenakenstraat": (51.60308, 4.781016),
    "Fijnaart-Zwingelspaansedijk": (51.653729, 4.515271),
    "Veldhoven-Europalaan": (51.407365, 5.393328),
    "Zierikzee-Lange Slikweg": (51.634706, 3.916623),
    "Philippine-Stelleweg": (51.294498, 3.749484),
    "Den Haag-Rebecquestraat": (52.077148, 4.289185),
    "Rotterdam-Schiedamsevest": (51.914233, 4.479923),
    "Vlaardingen-Floreslaan": (51.910474, 4.326303),
    "Westmaas-Groeneweg": (51.786579, 4.450529),
    "Dordrecht-Bamendaweg": (51.800658, 4.708239),
    "De Zilk-Vogelaarsdreef": (52.296556, 4.510817),
    "Den Haag-Veerkade": (52.075071, 4.315872),
    "Den Haag-Bleriotlaan": (52.039023, 4.359376),
    "Wieringerwerf-Medemblikkerweg": (52.803657, 5.050509),
    "Hilversum-J. Gerardtsweg": (52.235083, 5.181552),
    "Laren-Jagerspad": (52.257356, 5.235903),
    "Haarlem-Schipholweg": (52.370508, 4.642319),
    "Biddinghuizen-Kuilweg": (52.423214, 5.593378),
    "Zegveld-Oude Meije": (52.13795, 4.83819),
    "Utrecht-Kardinaal de Jongweg": (52.105031, 5.124464),
    "Utrecht-Constant Erzeijstraat": (52.067748, 5.120507),
    "Breukelen-Snelweg": (52.20153, 4.987444),
    "Utrecht-Griftpark": (52.101308, 5.128183),
    "Cabauw-Wielsekade": (51.974489, 4.923301),
    "Eibergen-Lintveldseweg": (52.091801, 6.605367),
    "Wekerom-Riemterdijk": (52.111621, 5.708419),
    "Nijmegen-Graafseweg": (51.841372, 5.857777),
    "Nijmegen-Ruyterstraat": (51.838221, 5.856938),
    "Hellendoorn-Luttenbergerweg": (52.388272, 6.402933),
    "Barsbeek-De Veenen": (52.654144, 6.017571),
    "Balk-Trophornsterweg": (52.916915, 5.573491),
    "Valthermond-Noorderdiep": (52.875725, 6.932432),
    "Kollumerwaard-Hooge Zuidwal": (53.330425, 6.276815),
    "Groningen-Europaweg": (53.217796, 6.578901),
    "Groningen-Nijensteinheerd": (53.246535, 6.608937),
    "Amsterdam-Haarlemmerweg": (52.385422, 4.87575),
    "Amsterdam-Nieuwendammerdijk": (52.389314, 4.943822),
    "Amsterdam-Einsteinweg": (52.381331, 4.845233),
    "Amsterdam-Van Diemenstraat": (52.389983, 4.887811),
    "Amsterdam-Vondelpark": (52.359714, 4.866208),
    "Amsterdam-Stadhouderskade": (52.358039, 4.8997),
    "Amsterdam-Oude Schans": (52.372056, 4.9044),
    "Amsterdam-Jan van Galenstraat": (52.374786, 4.860319),
    "Amsterdam-Kantershof (Zuid Oost)": (52.320692, 4.988397),
    "Amsterdam-Sportpark Ookmeer (Osdorp)": (52.366811, 4.793344),
    "Zaanstad-Hemkade": (52.42023, 4.83206),
    "IJmuiden-Kanaaldijk": (52.463039, 4.601842),
    "Wijk aan Zee-Burgemeester Rothestraat": (52.493992, 4.601986),
    "Badhoevedorp-Sloterweg": (52.334003, 4.774006),
    "Hoofddorp-Hoofdweg": (52.327464, 4.715008),
    "Oude Meer-Aalsmeerderdijk": (52.279991, 4.770773),
    "Zaandam-Wagenschotpad": (52.448011, 4.816706),
    "Amsterdam-Spaarnwoude": (52.398437, 4.728581),
    "Amsterdam-Hoogtij": (52.428017, 4.773478),
    "Geleen-Vouershof": (50.963087, 5.810702),
    "Geleen-Asterstraat": (50.984447, 5.822233),
    "Maastricht-A2 Nassaulaan": (50.845941, 5.714745),
    "Ossendrecht Burgermeester Voetenstraat": (51.39324, 4.3202),
    "Moerdijk Julianastraat": (51.699409, 4.623713),
    "Klundert Kerkweg": (51.668936, 4.541659),
    "Zevenbergen Galgenweg": (51.653205, 4.594882),
    "Strijensas Buitendijk": (51.713396, 4.583248),
    "Arnhem-Pleijroute Velperbroek": (51.978328, 5.969485),
}


# Convert station data into a DataFrame for better handling
stations_df = pd.DataFrame.from_dict(stations, orient='index', columns=['Latitude', 'Longitude'])

# Calculate the distance matrix using haversine formula or Euclidean distance
def haversine(lat1, lon1, lat2, lon2):
    # Earth radius in kilometers
    R = 6371.0
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    return R * c

# Compute pairwise distances
coords = stations_df.to_numpy()
distance_matrix = np.zeros((len(coords), len(coords)))

for i in range(len(coords)):
    for j in range(len(coords)):
        distance_matrix[i, j] = haversine(coords[i][0], coords[i][1], coords[j][0], coords[j][1])

# Create a DataFrame for better visualization of distances
distance_matrix_df = pd.DataFrame(distance_matrix, index=stations.keys(), columns=stations.keys())

# Optional: Compute an inverse-weighted matrix
epsilon = 1e-5  # Small value to avoid division by zero
inverse_matrix = 1 / (distance_matrix + epsilon)
inverse_matrix_df = pd.DataFrame(inverse_matrix, index=stations.keys(), columns=stations.keys())

# Print results
print("Distance Matrix (km):")
print(distance_matrix_df)

print("\nInverse Weighted Matrix:")
print(inverse_matrix_df)
# Out:
# Distance Matrix (km):
#                                  Hoogvliet-Leemkuil  Rotterdam Zuid-Pleinweg  \
# Hoogvliet-Leemkuil                         0.000000                 9.006514
# Rotterdam Zuid-Pleinweg                    9.006514                 0.000000
# Rotterdam Zuid-Zwartewaalstraat            9.536355                 0.543712
# Ridderkerk-Hogeweg                        15.437377                 7.235572
# Rotterdam-Oost Sidelinge A13               9.446191                 6.281071
# ...                                             ...                      ...
# Moerdijk Julianastraat                    26.268615                23.479740
# Klundert Kerkweg                          25.526662                25.062199
# Zevenbergen Galgenweg                     28.971472                27.599940
# Strijensas Buitendijk                     23.220906                20.985354
# Arnhem-Pleijroute Velperbroek            111.381438               102.526585
#
#                                  Rotterdam Zuid-Zwartewaalstraat  \
# Hoogvliet-Leemkuil                                      9.536355
# Rotterdam Zuid-Pleinweg                                 0.543712
# Rotterdam Zuid-Zwartewaalstraat                         0.000000
# Ridderkerk-Hogeweg                                      6.897139
# Rotterdam-Oost Sidelinge A13                            6.330290
# ...                                                          ...
# Moerdijk Julianastraat                                 23.538279
# Klundert Kerkweg                                       25.259379
# Zevenbergen Galgenweg                                  27.734284
# Strijensas Buitendijk                                  21.092767
# Arnhem-Pleijroute Velperbroek                         102.031416
#
#                                  Ridderkerk-Hogeweg  \
# Hoogvliet-Leemkuil                        15.437377
# Rotterdam Zuid-Pleinweg                    7.235572
# Rotterdam Zuid-Zwartewaalstraat            6.897139
# Ridderkerk-Hogeweg                         0.000000
# Rotterdam-Oost Sidelinge A13              12.804033
# ...                                             ...
# Moerdijk Julianastraat                    19.142586
# Klundert Kerkweg                          22.450060
# Zevenbergen Galgenweg                     24.064870
# Strijensas Buitendijk                     17.351687
# Arnhem-Pleijroute Velperbroek             96.044489
#
#                                  Rotterdam-Oost Sidelinge A13  \
# Hoogvliet-Leemkuil                                   9.446191
# Rotterdam Zuid-Pleinweg                              6.281071
# Rotterdam Zuid-Zwartewaalstraat                      6.330290
# Ridderkerk-Hogeweg                                  12.804033
# Rotterdam-Oost Sidelinge A13                         0.000000
# ...                                                       ...
# Moerdijk Julianastraat                              29.709490
# Klundert Kerkweg                                    30.926973
# Zevenbergen Galgenweg                               33.669980
# Strijensas Buitendijk                               27.134591
# Arnhem-Pleijroute Velperbroek                      105.532344
#
#                                  Rotterdam Noord -Statenweg  \
# Hoogvliet-Leemkuil                                 9.852376
# Rotterdam Zuid-Pleinweg                            4.213463
# Rotterdam Zuid-Zwartewaalstraat                    4.134835
# Ridderkerk-Hogeweg                                10.367441
# Rotterdam-Oost Sidelinge A13                       2.452009
# ...                                                     ...
# Moerdijk Julianastraat                            27.670434
# Klundert Kerkweg                                  29.234197
# Zevenbergen Galgenweg                             31.811666
# Strijensas Buitendijk                             25.197878
# Arnhem-Pleijroute Velperbroek                    103.508902
#
#                                  Schiedam-Alphons Arienstraat  \
# Hoogvliet-Leemkuil                                   6.786185
# Rotterdam Zuid-Pleinweg                              6.395601
# Rotterdam Zuid-Zwartewaalstraat                      6.667388
# Ridderkerk-Hogeweg                                  13.553064
# Rotterdam-Oost Sidelinge A13                         2.764969
# ...                                                       ...
# Moerdijk Julianastraat                              29.032084
# Klundert Kerkweg                                    29.682716
# Zevenbergen Galgenweg                               32.655837
# Strijensas Buitendijk                               26.289829
# Arnhem-Pleijroute Velperbroek                      107.653831
#
#                                  Maassluis-Kwartellaan  \
# Hoogvliet-Leemkuil                           11.306232
# Rotterdam Zuid-Pleinweg                      17.917724
# Rotterdam Zuid-Zwartewaalstraat              18.305280
# Ridderkerk-Hogeweg                           25.136281
# Rotterdam-Oost Sidelinge A13                 13.912720
# ...                                                ...
# Moerdijk Julianastraat                       37.535633
# Klundert Kerkweg                             36.345614
# Zevenbergen Galgenweg                        39.973514
# Strijensas Buitendijk                        34.454619
# Arnhem-Pleijroute Velperbroek               119.445024
#
#                                  Hoek v. Holland-Berghaven  \
# Hoogvliet-Leemkuil                               20.165260
# Rotterdam Zuid-Pleinweg                          26.415241
# Rotterdam Zuid-Zwartewaalstraat                  26.754311
# Ridderkerk-Hogeweg                               33.647074
# Rotterdam-Oost Sidelinge A13                     21.603454
# ...                                                    ...
# Moerdijk Julianastraat                           46.332648
# Klundert Kerkweg                                 44.851242
# Zevenbergen Galgenweg                            48.575948
# Strijensas Buitendijk                            43.227058
# Arnhem-Pleijroute Velperbroek                   126.538338
#
#                                  Alblasserdam-De Helling  ...  \
# Hoogvliet-Leemkuil                             20.962127  ...
# Rotterdam Zuid-Pleinweg                        12.860699  ...
# Rotterdam Zuid-Zwartewaalstraat                12.496064  ...
# Ridderkerk-Hogeweg                              5.645137  ...
# Rotterdam-Oost Sidelinge A13                   18.112888  ...
# ...                                                  ...  ...
# Moerdijk Julianastraat                         17.800489  ...
# Klundert Kerkweg                               22.537953  ...
# Zevenbergen Galgenweg                          23.199765  ...
# Strijensas Buitendijk                          16.915788  ...
# Arnhem-Pleijroute Velperbroek                  90.792593  ...
#
#                                  Amsterdam-Hoogtij  Geleen-Vouershof  \
# Hoogvliet-Leemkuil                       68.557828        142.470563
# Rotterdam Zuid-Pleinweg                  62.949439        138.386903
# Rotterdam Zuid-Zwartewaalstraat          62.541833        138.275247
# Ridderkerk-Hogeweg                       63.498420        132.056922
# Rotterdam-Oost Sidelinge A13             59.239478        144.590115
# ...                                            ...               ...
# Moerdijk Julianastraat                   81.661786        116.205934
# Klundert Kerkweg                         85.881627        118.060594
# Zevenbergen Galgenweg                    87.016736        114.151348
# Strijensas Buitendijk                    80.518891        119.290470
# Arnhem-Pleijroute Velperbroek            95.618850        113.424039
#
#                                  Geleen-Asterstraat  Maastricht-A2 Nassaulaan  \
# Hoogvliet-Leemkuil                       141.361573                147.685139
# Rotterdam Zuid-Pleinweg                  137.151111                144.378462
# Rotterdam Zuid-Zwartewaalstraat          137.031042                144.317599
# Ridderkerk-Hogeweg                       130.765499                138.414548
# Rotterdam-Oost Sidelinge A13             143.338328                150.646255
# ...                                             ...                       ...
# Moerdijk Julianastraat                   115.109055                121.515567
# Klundert Kerkweg                         117.087351                122.628557
# Zevenbergen Galgenweg                    113.156526                118.877604
# Strijensas Buitendijk                    118.208909                124.486550
# Arnhem-Pleijroute Velperbroek            110.983892                127.148859
#
#                                  Ossendrecht Burgermeester Voetenstraat  \
# Hoogvliet-Leemkuil                                            52.780855
# Rotterdam Zuid-Pleinweg                                       56.461434
# Rotterdam Zuid-Zwartewaalstraat                               56.824704
# Ridderkerk-Hogeweg                                            55.905098
# Rotterdam-Oost Sidelinge A13                                  61.104056
# ...                                                                 ...
# Moerdijk Julianastraat                                        39.993890
# Klundert Kerkweg                                              34.270399
# Zevenbergen Galgenweg                                         34.594042
# Strijensas Buitendijk                                         39.976265
# Arnhem-Pleijroute Velperbroek                                130.991417
#
#                                  Moerdijk Julianastraat  Klundert Kerkweg  \
# Hoogvliet-Leemkuil                            26.268615         25.526662
# Rotterdam Zuid-Pleinweg                       23.479740         25.062199
# Rotterdam Zuid-Zwartewaalstraat               23.538279         25.259379
# Ridderkerk-Hogeweg                            19.142586         22.450060
# Rotterdam-Oost Sidelinge A13                  29.709490         30.926973
# ...                                                 ...               ...
# Moerdijk Julianastraat                         0.000000          6.594036
# Klundert Kerkweg                               6.594036          0.000000
# Zevenbergen Galgenweg                          5.508853          4.066522
# Strijensas Buitendijk                          3.192732          5.714762
# Arnhem-Pleijroute Velperbroek                 97.521952        103.984984
#
#                                  Zevenbergen Galgenweg  Strijensas Buitendijk  \
# Hoogvliet-Leemkuil                           28.971472              23.220906
# Rotterdam Zuid-Pleinweg                      27.599940              20.985354
# Rotterdam Zuid-Zwartewaalstraat              27.734284              21.092767
# Ridderkerk-Hogeweg                           24.064870              17.351687
# Rotterdam-Oost Sidelinge A13                 33.669980              27.134591
# ...                                                ...                    ...
# Moerdijk Julianastraat                        5.508853               3.192732
# Klundert Kerkweg                              4.066522               5.714762
# Zevenbergen Galgenweg                         0.000000               6.740822
# Strijensas Buitendijk                         6.740822               0.000000
# Arnhem-Pleijroute Velperbroek               101.167779              99.676820
#
#                                  Arnhem-Pleijroute Velperbroek
# Hoogvliet-Leemkuil                                  111.381438
# Rotterdam Zuid-Pleinweg                             102.526585
# Rotterdam Zuid-Zwartewaalstraat                     102.031416
# Ridderkerk-Hogeweg                                   96.044489
# Rotterdam-Oost Sidelinge A13                        105.532344
# ...                                                        ...
# Moerdijk Julianastraat                               97.521952
# Klundert Kerkweg                                    103.984984
# Zevenbergen Galgenweg                               101.167779
# Strijensas Buitendijk                                99.676820
# Arnhem-Pleijroute Velperbroek                         0.000000
#
# [83 rows x 83 columns]
#
# Inverse Weighted Matrix:
#                                  Hoogvliet-Leemkuil  Rotterdam Zuid-Pleinweg  \
# Hoogvliet-Leemkuil                    100000.000000                 0.111031
# Rotterdam Zuid-Pleinweg                    0.111031            100000.000000
# Rotterdam Zuid-Zwartewaalstraat            0.104862                 1.839175
# Ridderkerk-Hogeweg                         0.064778                 0.138206
# Rotterdam-Oost Sidelinge A13               0.105863                 0.159208
# ...                                             ...                      ...
# Moerdijk Julianastraat                     0.038068                 0.042590
# Klundert Kerkweg                           0.039175                 0.039901
# Zevenbergen Galgenweg                      0.034517                 0.036232
# Strijensas Buitendijk                      0.043065                 0.047652
# Arnhem-Pleijroute Velperbroek              0.008978                 0.009754
#
#                                  Rotterdam Zuid-Zwartewaalstraat  \
# Hoogvliet-Leemkuil                                      0.104862
# Rotterdam Zuid-Pleinweg                                 1.839175
# Rotterdam Zuid-Zwartewaalstraat                    100000.000000
# Ridderkerk-Hogeweg                                      0.144987
# Rotterdam-Oost Sidelinge A13                            0.157970
# ...                                                          ...
# Moerdijk Julianastraat                                  0.042484
# Klundert Kerkweg                                        0.039589
# Zevenbergen Galgenweg                                   0.036056
# Strijensas Buitendijk                                   0.047410
# Arnhem-Pleijroute Velperbroek                           0.009801
#
#                                  Ridderkerk-Hogeweg  \
# Hoogvliet-Leemkuil                         0.064778
# Rotterdam Zuid-Pleinweg                    0.138206
# Rotterdam Zuid-Zwartewaalstraat            0.144987
# Ridderkerk-Hogeweg                    100000.000000
# Rotterdam-Oost Sidelinge A13               0.078100
# ...                                             ...
# Moerdijk Julianastraat                     0.052240
# Klundert Kerkweg                           0.044543
# Zevenbergen Galgenweg                      0.041554
# Strijensas Buitendijk                      0.057631
# Arnhem-Pleijroute Velperbroek              0.010412
#
#                                  Rotterdam-Oost Sidelinge A13  \
# Hoogvliet-Leemkuil                                   0.105863
# Rotterdam Zuid-Pleinweg                              0.159208
# Rotterdam Zuid-Zwartewaalstraat                      0.157970
# Ridderkerk-Hogeweg                                   0.078100
# Rotterdam-Oost Sidelinge A13                    100000.000000
# ...                                                       ...
# Moerdijk Julianastraat                               0.033659
# Klundert Kerkweg                                     0.032334
# Zevenbergen Galgenweg                                0.029700
# Strijensas Buitendijk                                0.036853
# Arnhem-Pleijroute Velperbroek                        0.009476
#
#                                  Rotterdam Noord -Statenweg  \
# Hoogvliet-Leemkuil                                 0.101498
# Rotterdam Zuid-Pleinweg                            0.237334
# Rotterdam Zuid-Zwartewaalstraat                    0.241847
# Ridderkerk-Hogeweg                                 0.096456
# Rotterdam-Oost Sidelinge A13                       0.407827
# ...                                                     ...
# Moerdijk Julianastraat                             0.036140
# Klundert Kerkweg                                   0.034207
# Zevenbergen Galgenweg                              0.031435
# Strijensas Buitendijk                              0.039686
# Arnhem-Pleijroute Velperbroek                      0.009661
#
#                                  Schiedam-Alphons Arienstraat  \
# Hoogvliet-Leemkuil                                   0.147358
# Rotterdam Zuid-Pleinweg                              0.156357
# Rotterdam Zuid-Zwartewaalstraat                      0.149984
# Ridderkerk-Hogeweg                                   0.073784
# Rotterdam-Oost Sidelinge A13                         0.361666
# ...                                                       ...
# Moerdijk Julianastraat                               0.034445
# Klundert Kerkweg                                     0.033690
# Zevenbergen Galgenweg                                0.030622
# Strijensas Buitendijk                                0.038038
# Arnhem-Pleijroute Velperbroek                        0.009289
#
#                                  Maassluis-Kwartellaan  \
# Hoogvliet-Leemkuil                            0.088447
# Rotterdam Zuid-Pleinweg                       0.055811
# Rotterdam Zuid-Zwartewaalstraat               0.054629
# Ridderkerk-Hogeweg                            0.039783
# Rotterdam-Oost Sidelinge A13                  0.071877
# ...                                                ...
# Moerdijk Julianastraat                        0.026641
# Klundert Kerkweg                              0.027514
# Zevenbergen Galgenweg                         0.025017
# Strijensas Buitendijk                         0.029024
# Arnhem-Pleijroute Velperbroek                 0.008372
#
#                                  Hoek v. Holland-Berghaven  \
# Hoogvliet-Leemkuil                                0.049590
# Rotterdam Zuid-Pleinweg                           0.037857
# Rotterdam Zuid-Zwartewaalstraat                   0.037377
# Ridderkerk-Hogeweg                                0.029720
# Rotterdam-Oost Sidelinge A13                      0.046289
# ...                                                    ...
# Moerdijk Julianastraat                            0.021583
# Klundert Kerkweg                                  0.022296
# Zevenbergen Galgenweg                             0.020586
# Strijensas Buitendijk                             0.023134
# Arnhem-Pleijroute Velperbroek                     0.007903
#
#                                  Alblasserdam-De Helling  ...  \
# Hoogvliet-Leemkuil                              0.047705  ...
# Rotterdam Zuid-Pleinweg                         0.077756  ...
# Rotterdam Zuid-Zwartewaalstraat                 0.080025  ...
# Ridderkerk-Hogeweg                              0.177143  ...
# Rotterdam-Oost Sidelinge A13                    0.055209  ...
# ...                                                  ...  ...
# Moerdijk Julianastraat                          0.056178  ...
# Klundert Kerkweg                                0.044370  ...
# Zevenbergen Galgenweg                           0.043104  ...
# Strijensas Buitendijk                           0.059116  ...
# Arnhem-Pleijroute Velperbroek                   0.011014  ...
#
#                                  Amsterdam-Hoogtij  Geleen-Vouershof  \
# Hoogvliet-Leemkuil                        0.014586          0.007019
# Rotterdam Zuid-Pleinweg                   0.015886          0.007226
# Rotterdam Zuid-Zwartewaalstraat           0.015989          0.007232
# Ridderkerk-Hogeweg                        0.015748          0.007572
# Rotterdam-Oost Sidelinge A13              0.016881          0.006916
# ...                                            ...               ...
# Moerdijk Julianastraat                    0.012246          0.008605
# Klundert Kerkweg                          0.011644          0.008470
# Zevenbergen Galgenweg                     0.011492          0.008760
# Strijensas Buitendijk                     0.012419          0.008383
# Arnhem-Pleijroute Velperbroek             0.010458          0.008816
#
#                                  Geleen-Asterstraat  Maastricht-A2 Nassaulaan  \
# Hoogvliet-Leemkuil                         0.007074                  0.006771
# Rotterdam Zuid-Pleinweg                    0.007291                  0.006926
# Rotterdam Zuid-Zwartewaalstraat            0.007298                  0.006929
# Ridderkerk-Hogeweg                         0.007647                  0.007225
# Rotterdam-Oost Sidelinge A13               0.006977                  0.006638
# ...                                             ...                       ...
# Moerdijk Julianastraat                     0.008687                  0.008229
# Klundert Kerkweg                           0.008541                  0.008155
# Zevenbergen Galgenweg                      0.008837                  0.008412
# Strijensas Buitendijk                      0.008460                  0.008033
# Arnhem-Pleijroute Velperbroek              0.009010                  0.007865
#
#                                  Ossendrecht Burgermeester Voetenstraat  \
# Hoogvliet-Leemkuil                                             0.018946
# Rotterdam Zuid-Pleinweg                                        0.017711
# Rotterdam Zuid-Zwartewaalstraat                                0.017598
# Ridderkerk-Hogeweg                                             0.017887
# Rotterdam-Oost Sidelinge A13                                   0.016366
# ...                                                                 ...
# Moerdijk Julianastraat                                         0.025004
# Klundert Kerkweg                                               0.029180
# Zevenbergen Galgenweg                                          0.028907
# Strijensas Buitendijk                                          0.025015
# Arnhem-Pleijroute Velperbroek                                  0.007634
#
#                                  Moerdijk Julianastraat  Klundert Kerkweg  \
# Hoogvliet-Leemkuil                             0.038068          0.039175
# Rotterdam Zuid-Pleinweg                        0.042590          0.039901
# Rotterdam Zuid-Zwartewaalstraat                0.042484          0.039589
# Ridderkerk-Hogeweg                             0.052240          0.044543
# Rotterdam-Oost Sidelinge A13                   0.033659          0.032334
# ...                                                 ...               ...
# Moerdijk Julianastraat                    100000.000000          0.151652
# Klundert Kerkweg                               0.151652     100000.000000
# Zevenbergen Galgenweg                          0.181526          0.245910
# Strijensas Buitendijk                          0.313210          0.174985
# Arnhem-Pleijroute Velperbroek                  0.010254          0.009617
#
#                                  Zevenbergen Galgenweg  Strijensas Buitendijk  \
# Hoogvliet-Leemkuil                            0.034517               0.043065
# Rotterdam Zuid-Pleinweg                       0.036232               0.047652
# Rotterdam Zuid-Zwartewaalstraat               0.036056               0.047410
# Ridderkerk-Hogeweg                            0.041554               0.057631
# Rotterdam-Oost Sidelinge A13                  0.029700               0.036853
# ...                                                ...                    ...
# Moerdijk Julianastraat                        0.181526               0.313210
# Klundert Kerkweg                              0.245910               0.174985
# Zevenbergen Galgenweg                    100000.000000               0.148350
# Strijensas Buitendijk                         0.148350          100000.000000
# Arnhem-Pleijroute Velperbroek                 0.009885               0.010032
#
#                                  Arnhem-Pleijroute Velperbroek
# Hoogvliet-Leemkuil                                    0.008978
# Rotterdam Zuid-Pleinweg                               0.009754
# Rotterdam Zuid-Zwartewaalstraat                       0.009801
# Ridderkerk-Hogeweg                                    0.010412
# Rotterdam-Oost Sidelinge A13                          0.009476
# ...                                                        ...
# Moerdijk Julianastraat                                0.010254
# Klundert Kerkweg                                      0.009617
# Zevenbergen Galgenweg                                 0.009885
# Strijensas Buitendijk                                 0.010032
# Arnhem-Pleijroute Velperbroek                    100000.000000
#
# [83 rows x 83 columns]

# %%
import numpy as np
import pandas as pd
from scipy.spatial.distance import pdist, squareform


# Convert station data into a DataFrame for better handling
stations_df = pd.DataFrame.from_dict(stations, orient='index', columns=['Latitude', 'Longitude'])


# Using pdist and squareform for efficient pairwise distance calculation
coords = stations_df.to_numpy()
distance_matrix = pdist(coords, metric='euclidean')  # You can switch to 'haversine' for better geographic distance
distance_matrix = squareform(distance_matrix)

# Create a DataFrame for better visualization of distances
distance_matrix_df = pd.DataFrame(distance_matrix, index=stations.keys(), columns=stations.keys())

# Optional: Compute an inverse-weighted matrix
epsilon = 1e-5  # Small value to avoid division by zero
inverse_matrix = 1 / (distance_matrix + epsilon)
inverse_matrix_df = pd.DataFrame(inverse_matrix, index=stations.keys(), columns=stations.keys())

# Print results
print("Distance Matrix (km):")
print(distance_matrix_df)

print("\nInverse Weighted Matrix:")
print(inverse_matrix_df)
# Out:
# Distance Matrix (km):
#                                  Hoogvliet-Leemkuil  Rotterdam Zuid-Pleinweg  \
# Hoogvliet-Leemkuil                         0.000000                 0.127674
# Rotterdam Zuid-Pleinweg                    0.127674                 0.000000
# Rotterdam Zuid-Zwartewaalstraat            0.134857                 0.007270
# Ridderkerk-Hogeweg                         0.224825                 0.101713
# Rotterdam-Oost Sidelinge A13               0.103645                 0.068844
# ...                                             ...                      ...
# Moerdijk Julianastraat                     0.316704                 0.239205
# Klundert Kerkweg                           0.272293                 0.230423
# Zevenbergen Galgenweg                      0.321421                 0.263925
# Strijensas Buitendijk                      0.275150                 0.205216
# Arnhem-Pleijroute Velperbroek              1.618049                 1.491345
#
#                                  Rotterdam Zuid-Zwartewaalstraat  \
# Hoogvliet-Leemkuil                                      0.134857
# Rotterdam Zuid-Pleinweg                                 0.007270
# Rotterdam Zuid-Zwartewaalstraat                         0.000000
# Ridderkerk-Hogeweg                                      0.095639
# Rotterdam-Oost Sidelinge A13                            0.072404
# ...                                                          ...
# Moerdijk Julianastraat                                  0.237198
# Klundert Kerkweg                                        0.231110
# Zevenbergen Galgenweg                                   0.263292
# Strijensas Buitendijk                                   0.204064
# Arnhem-Pleijroute Velperbroek                           1.484376
#
#                                  Ridderkerk-Hogeweg  \
# Hoogvliet-Leemkuil                         0.224825
# Rotterdam Zuid-Pleinweg                    0.101713
# Rotterdam Zuid-Zwartewaalstraat            0.095639
# Ridderkerk-Hogeweg                         0.000000
# Rotterdam-Oost Sidelinge A13               0.164550
# ...                                             ...
# Moerdijk Julianastraat                     0.175537
# Klundert Kerkweg                           0.204139
# Zevenbergen Galgenweg                      0.216734
# Strijensas Buitendijk                      0.156068
# Arnhem-Pleijroute Velperbroek              1.393688
#
#                                  Rotterdam-Oost Sidelinge A13  \
# Hoogvliet-Leemkuil                                   0.103645
# Rotterdam Zuid-Pleinweg                              0.068844
# Rotterdam Zuid-Zwartewaalstraat                      0.072404
# Ridderkerk-Hogeweg                                   0.164550
# Rotterdam-Oost Sidelinge A13                         0.000000
# ...                                                       ...
# Moerdijk Julianastraat                               0.307259
# Klundert Kerkweg                                     0.291485
# Zevenbergen Galgenweg                                0.329144
# Strijensas Buitendijk                                0.271905
# Arnhem-Pleijroute Velperbroek                        1.539309
#
#                                  Rotterdam Noord -Statenweg  \
# Hoogvliet-Leemkuil                                 0.121745
# Rotterdam Zuid-Pleinweg                            0.040837
# Rotterdam Zuid-Zwartewaalstraat                    0.042514
# Ridderkerk-Hogeweg                                 0.131985
# Rotterdam-Oost Sidelinge A13                       0.032690
# ...                                                     ...
# Moerdijk Julianastraat                             0.279664
# Klundert Kerkweg                                   0.270379
# Zevenbergen Galgenweg                              0.304724
# Strijensas Buitendijk                              0.246038
# Arnhem-Pleijroute Velperbroek                      1.509010
#
#                                  Schiedam-Alphons Arienstraat  \
# Hoogvliet-Leemkuil                                   0.071015
# Rotterdam Zuid-Pleinweg                              0.084872
# Rotterdam Zuid-Zwartewaalstraat                      0.090505
# Ridderkerk-Hogeweg                                   0.186071
# Rotterdam-Oost Sidelinge A13                         0.033919
# ...                                                       ...
# Moerdijk Julianastraat                               0.314170
# Klundert Kerkweg                                     0.288805
# Zevenbergen Galgenweg                                0.330700
# Strijensas Buitendijk                                0.276286
# Arnhem-Pleijroute Velperbroek                        1.569129
#
#                                  Maassluis-Kwartellaan  \
# Hoogvliet-Leemkuil                            0.142692
# Rotterdam Zuid-Pleinweg                       0.255953
# Rotterdam Zuid-Zwartewaalstraat               0.262332
# Ridderkerk-Hogeweg                            0.357557
# Rotterdam-Oost Sidelinge A13                  0.202769
# ...                                                ...
# Moerdijk Julianastraat                        0.459005
# Klundert Kerkweg                              0.409377
# Zevenbergen Galgenweg                         0.460795
# Strijensas Buitendijk                         0.417119
# Arnhem-Pleijroute Velperbroek                 1.742075
#
#                                  Hoek v. Holland-Berghaven  \
# Hoogvliet-Leemkuil                                0.258098
# Rotterdam Zuid-Pleinweg                           0.369064
# Rotterdam Zuid-Zwartewaalstraat                   0.375152
# Ridderkerk-Hogeweg                                0.470758
# Rotterdam-Oost Sidelinge A13                      0.311243
# ...                                                    ...
# Moerdijk Julianastraat                            0.573825
# Klundert Kerkweg                                  0.521114
# Zevenbergen Galgenweg                             0.573615
# Strijensas Buitendijk                             0.531707
# Arnhem-Pleijroute Velperbroek                     1.847541
#
#                                  Alblasserdam-De Helling  ...  \
# Hoogvliet-Leemkuil                              0.305026  ...
# Rotterdam Zuid-Pleinweg                         0.182484  ...
# Rotterdam Zuid-Zwartewaalstraat                 0.176249  ...
# Ridderkerk-Hogeweg                              0.080888  ...
# Rotterdam-Oost Sidelinge A13                    0.243165  ...
# ...                                                  ...  ...
# Moerdijk Julianastraat                          0.162619  ...
# Klundert Kerkweg                                0.223026  ...
# Zevenbergen Galgenweg                           0.214840  ...
# Strijensas Buitendijk                           0.163679  ...
# Arnhem-Pleijroute Velperbroek                   1.314891  ...
#
#                                  Amsterdam-Hoogtij  Geleen-Vouershof  \
# Hoogvliet-Leemkuil                        0.699429          1.713524
# Rotterdam Zuid-Pleinweg                   0.611518          1.621798
# Rotterdam Zuid-Zwartewaalstraat           0.606095          1.617614
# Ridderkerk-Hogeweg                        0.591126          1.528380
# Rotterdam-Oost Sidelinge A13              0.597626          1.689912
# ...                                            ...               ...
# Moerdijk Julianastraat                    0.743841          1.396822
# Klundert Kerkweg                          0.793690          1.452134
# Zevenbergen Galgenweg                     0.795129          1.398028
# Strijensas Buitendijk                     0.739507          1.438613
# Arnhem-Pleijroute Velperbroek             1.277753          1.027583
#
#                                  Geleen-Asterstraat  Maastricht-A2 Nassaulaan  \
# Hoogvliet-Leemkuil                         1.712217                  1.700485
# Rotterdam Zuid-Pleinweg                    1.619210                  1.617204
# Rotterdam Zuid-Zwartewaalstraat            1.614939                  1.613594
# Ridderkerk-Hogeweg                         1.525187                  1.528086
# Rotterdam-Oost Sidelinge A13               1.687172                  1.685947
# ...                                             ...                       ...
# Moerdijk Julianastraat                     1.395572                  1.385193
# Klundert Kerkweg                           1.452031                  1.432987
# Zevenbergen Galgenweg                      1.397722                  1.380496
# Strijensas Buitendijk                      1.437515                  1.425750
# Arnhem-Pleijroute Velperbroek              1.004730                  1.160686
#
#                                  Ossendrecht Burgermeester Voetenstraat  \
# Hoogvliet-Leemkuil                                             0.475464
# Rotterdam Zuid-Pleinweg                                        0.523133
# Rotterdam Zuid-Zwartewaalstraat                                0.527613
# Ridderkerk-Hogeweg                                             0.542480
# Rotterdam-Oost Sidelinge A13                                   0.556315
# ...                                                                 ...
# Moerdijk Julianastraat                                         0.431114
# Klundert Kerkweg                                               0.353627
# Zevenbergen Galgenweg                                          0.378196
# Strijensas Buitendijk                                          0.414360
# Arnhem-Pleijroute Velperbroek                                  1.749991
#
#                                  Moerdijk Julianastraat  Klundert Kerkweg  \
# Hoogvliet-Leemkuil                             0.316704          0.272293
# Rotterdam Zuid-Pleinweg                        0.239205          0.230423
# Rotterdam Zuid-Zwartewaalstraat                0.237198          0.231110
# Ridderkerk-Hogeweg                             0.175537          0.204139
# Rotterdam-Oost Sidelinge A13                   0.307259          0.291485
# ...                                                 ...               ...
# Moerdijk Julianastraat                         0.000000          0.087530
# Klundert Kerkweg                               0.087530          0.000000
# Zevenbergen Galgenweg                          0.054461          0.055499
# Strijensas Buitendijk                          0.042814          0.060880
# Arnhem-Pleijroute Velperbroek                  1.374372          1.460962
#
#                                  Zevenbergen Galgenweg  Strijensas Buitendijk  \
# Hoogvliet-Leemkuil                            0.321421               0.275150
# Rotterdam Zuid-Pleinweg                       0.263925               0.205216
# Rotterdam Zuid-Zwartewaalstraat               0.263292               0.204064
# Ridderkerk-Hogeweg                            0.216734               0.156068
# Rotterdam-Oost Sidelinge A13                  0.329144               0.271905
# ...                                                ...                    ...
# Moerdijk Julianastraat                        0.054461               0.042814
# Klundert Kerkweg                              0.055499               0.060880
# Zevenbergen Galgenweg                         0.000000               0.061305
# Strijensas Buitendijk                         0.061305               0.000000
# Arnhem-Pleijroute Velperbroek                 1.412529               1.411326
#
#                                  Arnhem-Pleijroute Velperbroek
# Hoogvliet-Leemkuil                                    1.618049
# Rotterdam Zuid-Pleinweg                               1.491345
# Rotterdam Zuid-Zwartewaalstraat                       1.484376
# Ridderkerk-Hogeweg                                    1.393688
# Rotterdam-Oost Sidelinge A13                          1.539309
# ...                                                        ...
# Moerdijk Julianastraat                                1.374372
# Klundert Kerkweg                                      1.460962
# Zevenbergen Galgenweg                                 1.412529
# Strijensas Buitendijk                                 1.411326
# Arnhem-Pleijroute Velperbroek                         0.000000
#
# [83 rows x 83 columns]
#
# Inverse Weighted Matrix:
#                                  Hoogvliet-Leemkuil  Rotterdam Zuid-Pleinweg  \
# Hoogvliet-Leemkuil                    100000.000000                 7.831847
# Rotterdam Zuid-Pleinweg                    7.831847            100000.000000
# Rotterdam Zuid-Zwartewaalstraat            7.414727               137.354535
# Ridderkerk-Hogeweg                         4.447705                 9.830595
# Rotterdam-Oost Sidelinge A13               9.647351                14.523547
# ...                                             ...                      ...
# Moerdijk Julianastraat                     3.157424                 4.180340
# Klundert Kerkweg                           3.672376                 4.339649
# Zevenbergen Galgenweg                      3.111086                 3.788817
# Strijensas Buitendijk                      3.634253                 4.872680
# Arnhem-Pleijroute Velperbroek              0.618024                 0.670531
#
#                                  Rotterdam Zuid-Zwartewaalstraat  \
# Hoogvliet-Leemkuil                                      7.414727
# Rotterdam Zuid-Pleinweg                               137.354535
# Rotterdam Zuid-Zwartewaalstraat                    100000.000000
# Ridderkerk-Hogeweg                                     10.454924
# Rotterdam-Oost Sidelinge A13                           13.809533
# ...                                                          ...
# Moerdijk Julianastraat                                  4.215702
# Klundert Kerkweg                                        4.326761
# Zevenbergen Galgenweg                                   3.797917
# Strijensas Buitendijk                                   4.900194
# Arnhem-Pleijroute Velperbroek                           0.673679
#
#                                  Ridderkerk-Hogeweg  \
# Hoogvliet-Leemkuil                         4.447705
# Rotterdam Zuid-Pleinweg                    9.830595
# Rotterdam Zuid-Zwartewaalstraat           10.454924
# Ridderkerk-Hogeweg                    100000.000000
# Rotterdam-Oost Sidelinge A13               6.076793
# ...                                             ...
# Moerdijk Julianastraat                     5.696480
# Klundert Kerkweg                           4.898383
# Zevenbergen Galgenweg                      4.613747
# Strijensas Buitendijk                      6.407069
# Arnhem-Pleijroute Velperbroek              0.717516
#
#                                  Rotterdam-Oost Sidelinge A13  \
# Hoogvliet-Leemkuil                                   9.647351
# Rotterdam Zuid-Pleinweg                             14.523547
# Rotterdam Zuid-Zwartewaalstraat                     13.809533
# Ridderkerk-Hogeweg                                   6.076793
# Rotterdam-Oost Sidelinge A13                    100000.000000
# ...                                                       ...
# Moerdijk Julianastraat                               3.254475
# Klundert Kerkweg                                     3.430594
# Zevenbergen Galgenweg                                3.038094
# Strijensas Buitendijk                                3.677615
# Arnhem-Pleijroute Velperbroek                        0.649638
#
#                                  Rotterdam Noord -Statenweg  \
# Hoogvliet-Leemkuil                                 8.213248
# Rotterdam Zuid-Pleinweg                           24.481481
# Rotterdam Zuid-Zwartewaalstraat                   23.516069
# Ridderkerk-Hogeweg                                 7.576054
# Rotterdam-Oost Sidelinge A13                      30.581307
# ...                                                     ...
# Moerdijk Julianastraat                             3.575593
# Klundert Kerkweg                                   3.698375
# Zevenbergen Galgenweg                              3.281547
# Strijensas Buitendijk                              4.064248
# Arnhem-Pleijroute Velperbroek                      0.662682
#
#                                  Schiedam-Alphons Arienstraat  \
# Hoogvliet-Leemkuil                                  14.079494
# Rotterdam Zuid-Pleinweg                             11.781085
# Rotterdam Zuid-Zwartewaalstraat                     11.047855
# Ridderkerk-Hogeweg                                   5.374017
# Rotterdam-Oost Sidelinge A13                        29.473361
# ...                                                       ...
# Moerdijk Julianastraat                               3.182884
# Klundert Kerkweg                                     3.462427
# Zevenbergen Galgenweg                                3.023801
# Strijensas Buitendijk                                3.619311
# Arnhem-Pleijroute Velperbroek                        0.637292
#
#                                  Maassluis-Kwartellaan  \
# Hoogvliet-Leemkuil                            7.007621
# Rotterdam Zuid-Pleinweg                       3.906820
# Rotterdam Zuid-Zwartewaalstraat               3.811819
# Ridderkerk-Hogeweg                            2.796679
# Rotterdam-Oost Sidelinge A13                  4.931475
# ...                                                ...
# Moerdijk Julianastraat                        2.178577
# Klundert Kerkweg                              2.442677
# Zevenbergen Galgenweg                         2.170113
# Strijensas Buitendijk                         2.397341
# Arnhem-Pleijroute Velperbroek                 0.574025
#
#                                  Hoek v. Holland-Berghaven  \
# Hoogvliet-Leemkuil                                3.874354
# Rotterdam Zuid-Pleinweg                           2.709487
# Rotterdam Zuid-Zwartewaalstraat                   2.665516
# Ridderkerk-Hogeweg                                2.124189
# Rotterdam-Oost Sidelinge A13                      3.212820
# ...                                                    ...
# Moerdijk Julianastraat                            1.742661
# Klundert Kerkweg                                  1.918930
# Zevenbergen Galgenweg                             1.743299
# Strijensas Buitendijk                             1.880699
# Arnhem-Pleijroute Velperbroek                     0.541257
#
#                                  Alblasserdam-De Helling  ...  \
# Hoogvliet-Leemkuil                              3.278298  ...
# Rotterdam Zuid-Pleinweg                         5.479626  ...
# Rotterdam Zuid-Zwartewaalstraat                 5.673470  ...
# Ridderkerk-Hogeweg                             12.361227  ...
# Rotterdam-Oost Sidelinge A13                    4.112270  ...
# ...                                                  ...  ...
# Moerdijk Julianastraat                          6.148973  ...
# Klundert Kerkweg                                4.483590  ...
# Zevenbergen Galgenweg                           4.654419  ...
# Strijensas Buitendijk                           6.109158  ...
# Arnhem-Pleijroute Velperbroek                   0.760513  ...
#
#                                  Amsterdam-Hoogtij  Geleen-Vouershof  \
# Hoogvliet-Leemkuil                        1.429718          0.583589
# Rotterdam Zuid-Pleinweg                   1.635248          0.616596
# Rotterdam Zuid-Zwartewaalstraat           1.649880          0.618191
# Ridderkerk-Hogeweg                        1.691659          0.654283
# Rotterdam-Oost Sidelinge A13              1.673260          0.591743
# ...                                            ...               ...
# Moerdijk Julianastraat                    1.344356          0.715905
# Klundert Kerkweg                          1.259922          0.688637
# Zevenbergen Galgenweg                     1.257642          0.715288
# Strijensas Buitendijk                     1.352234          0.695109
# Arnhem-Pleijroute Velperbroek             0.782618          0.973148
#
#                                  Geleen-Asterstraat  Maastricht-A2 Nassaulaan  \
# Hoogvliet-Leemkuil                         0.584035                  0.588064
# Rotterdam Zuid-Pleinweg                    0.617581                  0.618348
# Rotterdam Zuid-Zwartewaalstraat            0.619215                  0.619731
# Ridderkerk-Hogeweg                         0.655653                  0.654409
# Rotterdam-Oost Sidelinge A13               0.592704                  0.593135
# ...                                             ...                       ...
# Moerdijk Julianastraat                     0.716547                  0.721916
# Klundert Kerkweg                           0.688686                  0.697838
# Zevenbergen Galgenweg                      0.715445                  0.724372
# Strijensas Buitendijk                      0.695640                  0.701380
# Arnhem-Pleijroute Velperbroek              0.995282                  0.861552
#
#                                  Ossendrecht Burgermeester Voetenstraat  \
# Hoogvliet-Leemkuil                                             2.103164
# Rotterdam Zuid-Pleinweg                                        1.911522
# Rotterdam Zuid-Zwartewaalstraat                                1.895292
# Ridderkerk-Hogeweg                                             1.843354
# Rotterdam-Oost Sidelinge A13                                   1.797510
# ...                                                                 ...
# Moerdijk Julianastraat                                         2.319516
# Klundert Kerkweg                                               2.827755
# Zevenbergen Galgenweg                                          2.644064
# Strijensas Buitendijk                                          2.413303
# Arnhem-Pleijroute Velperbroek                                  0.571428
#
#                                  Moerdijk Julianastraat  Klundert Kerkweg  \
# Hoogvliet-Leemkuil                             3.157424          3.672376
# Rotterdam Zuid-Pleinweg                        4.180340          4.339649
# Rotterdam Zuid-Zwartewaalstraat                4.215702          4.326761
# Ridderkerk-Hogeweg                             5.696480          4.898383
# Rotterdam-Oost Sidelinge A13                   3.254475          3.430594
# ...                                                 ...               ...
# Moerdijk Julianastraat                    100000.000000         11.423378
# Klundert Kerkweg                              11.423378     100000.000000
# Zevenbergen Galgenweg                         18.358282         18.015058
# Strijensas Buitendijk                         23.351304         16.423142
# Arnhem-Pleijroute Velperbroek                  0.727600          0.684476
#
#                                  Zevenbergen Galgenweg  Strijensas Buitendijk  \
# Hoogvliet-Leemkuil                            3.111086               3.634253
# Rotterdam Zuid-Pleinweg                       3.788817               4.872680
# Rotterdam Zuid-Zwartewaalstraat               3.797917               4.900194
# Ridderkerk-Hogeweg                            4.613747               6.407069
# Rotterdam-Oost Sidelinge A13                  3.038094               3.677615
# ...                                                ...                    ...
# Moerdijk Julianastraat                       18.358282              23.351304
# Klundert Kerkweg                             18.015058              16.423142
# Zevenbergen Galgenweg                    100000.000000              16.309215
# Strijensas Buitendijk                        16.309215          100000.000000
# Arnhem-Pleijroute Velperbroek                 0.707945               0.708548
#
#                                  Arnhem-Pleijroute Velperbroek
# Hoogvliet-Leemkuil                                    0.618024
# Rotterdam Zuid-Pleinweg                               0.670531
# Rotterdam Zuid-Zwartewaalstraat                       0.673679
# Ridderkerk-Hogeweg                                    0.717516
# Rotterdam-Oost Sidelinge A13                          0.649638
# ...                                                        ...
# Moerdijk Julianastraat                                0.727600
# Klundert Kerkweg                                      0.684476
# Zevenbergen Galgenweg                                 0.707945
# Strijensas Buitendijk                                 0.708548
# Arnhem-Pleijroute Velperbroek                    100000.000000
#
# [83 rows x 83 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from transformers import AutoformerConfig, AutoformerForPrediction

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.utils.data import Dataset, DataLoader

import argparse
import sys
import platform
from glob import glob
from tqdm import tqdm
from typing import Tuple

import data

# %%
class UniDataset(Dataset):
    def __init__(self, df: pd.DataFrame, distance_matrix: np.ndarray, columns: str = None, in_days=4, out_days=14, device='cpu') -> None:
        if columns is None:
            columns = [col for col in df.columns if col.startswith('NL')][:83]

        self.variates = len(columns)
        self.x = torch.tensor(df[columns].values, dtype=torch.float32, device=device)
        self.h = torch.tensor(df['Hour'].values, dtype=torch.float32, device=device) / 24
        self.doy = torch.tensor(df['DayOfYear'].values, dtype=torch.float32, device=device) / 365

        self.in_samples, self.out_samples = 24 * in_days, 24 * out_days
        self.n = len(self.x) - 2 * (self.in_samples + self.out_samples)

        # Precompute spatial weights from the distance matrix
        weights = 1 / (1 + distance_matrix)  # Inverse distance weighting
        np.fill_diagonal(weights, 0)  # Exclude self-contribution
        self.spatial_weights = torch.tensor(weights, dtype=torch.float32, device=device)

    def __len__(self) -> int:
        return self.n

    def __getitem__(self, i: int) -> Tuple[torch.Tensor, torch.Tensor]:
        data = self.x[i:i + self.in_samples]
        data_time = torch.column_stack((
            self.h[i:i + self.in_samples],
            self.doy[i:i + self.in_samples],
        ))
        data_mask = ~data.isnan()
        target = self.x[i + self.in_samples:i + self.in_samples + self.out_samples]
        target_time = torch.column_stack((
            self.h[i + self.in_samples:i + self.in_samples + self.out_samples],
            self.doy[i + self.in_samples:i + self.in_samples + self.out_samples],
        ))

        # Compute spatially weighted aggregate for each time step
        spatial_features = torch.matmul(self.spatial_weights, self.x.T).T[i:i + self.in_samples]

        # Concatenate spatial features to data
        data_with_spatial = torch.cat([data, spatial_features], dim=1)

        return data_with_spatial, data_time, data_mask, target, target_time

# %%
def train(args, model, device, train_loader, optimizer, epoch) :
    model.train()

    loss_avg = 0
    for batch_idx, (data, data_time, data_mask, target, target_time) in tqdm(enumerate(train_loader), leave=False, total=args.batches_per_epoch) :
        optimizer.zero_grad()

        outputs = model(
            past_values=data,
            past_time_features=data_time,
            past_observed_mask=data_mask,
            future_values=target,
            future_time_features=target_time
        )
        loss = outputs.loss
        loss.backward()
        optimizer.step()

        loss_avg += (loss.item()/args.batches_per_epoch)
        if (batch_idx >= args.batches_per_epoch) : break
    
    return loss_avg

def eval(args, model, val_loader, epoch):
    model.eval()
    with torch.no_grad():
        rmse = 0
        for batch_idx, (data, data_time, data_mask, target, target_time) in tqdm(enumerate(val_loader), leave=False, total=args.batches_per_val) :
            outputs = model.generate(
                past_values=data,
                past_time_features=data_time,
                past_observed_mask=data_mask,
                future_time_features=target_time
            )

            pred = outputs.sequences.mean(dim=1)
            rmse += (target - pred).square().mean().sqrt() / args.batches_per_val
            if (batch_idx >= args.batches_per_val) : break

    return rmse.item()

# %%
stations = {
    "Hoogvliet-Leemkuil": (51.867411, 4.355242),
    "Rotterdam Zuid-Pleinweg": (51.891147, 4.48069),
    "Rotterdam Zuid-Zwartewaalstraat": (51.893617, 4.487528),
    "Ridderkerk-Hogeweg": (51.869431, 4.580058),
    "Rotterdam-Oost Sidelinge A13": (51.938472, 4.430692),
    "Rotterdam Noord -Statenweg": (51.927111, 4.461344),
    "Schiedam-Alphons Arienstraat": (51.921389, 4.401389),
    "Maassluis-Kwartellaan": (51.932039, 4.228025),
    "Hoek v. Holland-Berghaven": (51.977803, 4.121944),
    "Alblasserdam-De Helling": (51.8579, 4.66012),
    "Posterholt-Vlodropperweg": (51.119194, 6.042399),
    "Vredepeel-Vredeweg": (51.54052, 5.85307),
    "Wijnandsrade-Opfergeltstraat": (50.902281, 5.881748),
    "Heerlen-Looierstraat": (50.887959, 5.970496),
    "Heerlen-Jamboreepad": (50.900317, 5.986853),
    "Biest Houtakker-Biestsestraat": (51.51844, 5.14845),
    "Huijbergen-Vennekenstraat": (51.434443, 4.359835),
    "Eindhoven-Genovevalaan": (51.468662, 5.47235),
    "Eindhoven-Noordbrabantlaan": (51.444157, 5.444833),
    "Breda-Tilburgseweg": (51.593533, 4.824944),
    "Breda-Bastenakenstraat": (51.60308, 4.781016),
    "Fijnaart-Zwingelspaansedijk": (51.653729, 4.515271),
    "Veldhoven-Europalaan": (51.407365, 5.393328),
    "Zierikzee-Lange Slikweg": (51.634706, 3.916623),
    "Philippine-Stelleweg": (51.294498, 3.749484),
    "Den Haag-Rebecquestraat": (52.077148, 4.289185),
    "Rotterdam-Schiedamsevest": (51.914233, 4.479923),
    "Vlaardingen-Floreslaan": (51.910474, 4.326303),
    "Westmaas-Groeneweg": (51.786579, 4.450529),
    "Dordrecht-Bamendaweg": (51.800658, 4.708239),
    "De Zilk-Vogelaarsdreef": (52.296556, 4.510817),
    "Den Haag-Veerkade": (52.075071, 4.315872),
    "Den Haag-Bleriotlaan": (52.039023, 4.359376),
    "Wieringerwerf-Medemblikkerweg": (52.803657, 5.050509),
    "Hilversum-J. Gerardtsweg": (52.235083, 5.181552),
    "Laren-Jagerspad": (52.257356, 5.235903),
    "Haarlem-Schipholweg": (52.370508, 4.642319),
    "Biddinghuizen-Kuilweg": (52.423214, 5.593378),
    "Zegveld-Oude Meije": (52.13795, 4.83819),
    "Utrecht-Kardinaal de Jongweg": (52.105031, 5.124464),
    "Utrecht-Constant Erzeijstraat": (52.067748, 5.120507),
    "Breukelen-Snelweg": (52.20153, 4.987444),
    "Utrecht-Griftpark": (52.101308, 5.128183),
    "Cabauw-Wielsekade": (51.974489, 4.923301),
    "Eibergen-Lintveldseweg": (52.091801, 6.605367),
    "Wekerom-Riemterdijk": (52.111621, 5.708419),
    "Nijmegen-Graafseweg": (51.841372, 5.857777),
    "Nijmegen-Ruyterstraat": (51.838221, 5.856938),
    "Hellendoorn-Luttenbergerweg": (52.388272, 6.402933),
    "Barsbeek-De Veenen": (52.654144, 6.017571),
    "Balk-Trophornsterweg": (52.916915, 5.573491),
    "Valthermond-Noorderdiep": (52.875725, 6.932432),
    "Kollumerwaard-Hooge Zuidwal": (53.330425, 6.276815),
    "Groningen-Europaweg": (53.217796, 6.578901),
    "Groningen-Nijensteinheerd": (53.246535, 6.608937),
    "Amsterdam-Haarlemmerweg": (52.385422, 4.87575),
    "Amsterdam-Nieuwendammerdijk": (52.389314, 4.943822),
    "Amsterdam-Einsteinweg": (52.381331, 4.845233),
    "Amsterdam-Van Diemenstraat": (52.389983, 4.887811),
    "Amsterdam-Vondelpark": (52.359714, 4.866208),
    "Amsterdam-Stadhouderskade": (52.358039, 4.8997),
    "Amsterdam-Oude Schans": (52.372056, 4.9044),
    "Amsterdam-Jan van Galenstraat": (52.374786, 4.860319),
    "Amsterdam-Kantershof (Zuid Oost)": (52.320692, 4.988397),
    "Amsterdam-Sportpark Ookmeer (Osdorp)": (52.366811, 4.793344),
    "Zaanstad-Hemkade": (52.42023, 4.83206),
    "IJmuiden-Kanaaldijk": (52.463039, 4.601842),
    "Wijk aan Zee-Burgemeester Rothestraat": (52.493992, 4.601986),
    "Badhoevedorp-Sloterweg": (52.334003, 4.774006),
    "Hoofddorp-Hoofdweg": (52.327464, 4.715008),
    "Oude Meer-Aalsmeerderdijk": (52.279991, 4.770773),
    "Zaandam-Wagenschotpad": (52.448011, 4.816706),
    "Amsterdam-Spaarnwoude": (52.398437, 4.728581),
    "Amsterdam-Hoogtij": (52.428017, 4.773478),
    "Geleen-Vouershof": (50.963087, 5.810702),
    "Geleen-Asterstraat": (50.984447, 5.822233),
    "Maastricht-A2 Nassaulaan": (50.845941, 5.714745),
    "Ossendrecht Burgermeester Voetenstraat": (51.39324, 4.3202),
    "Moerdijk Julianastraat": (51.699409, 4.623713),
    "Klundert Kerkweg": (51.668936, 4.541659),
    "Zevenbergen Galgenweg": (51.653205, 4.594882),
    "Strijensas Buitendijk": (51.713396, 4.583248),
    "Arnhem-Pleijroute Velperbroek": (51.978328, 5.969485),
}
def haversine(lat1, lon1, lat2, lon2):
    # Earth radius in kilometers
    R = 6371.0
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    return R * c

# %%
def parse_args() -> argparse.Namespace :
    parser = argparse.ArgumentParser(description='Univariate Autoformer')
    parser.add_argument('--batch-size', type=int, default=32)
    parser.add_argument('--batches-per-epoch', type=int, default=100)
    parser.add_argument('--batches-per-val', type=int, default=8)
    parser.add_argument('--epochs', type=int, default=10)

    parser.add_argument('--in-days', type=int, default=4)
    parser.add_argument('--out-days', type=int, default=14)
    
    parser.add_argument('--no-cuda', action='store_true', default=False)

    return parser.parse_args()

def main(args):
    # Define the device first
    device = torch.device('cuda') if (not args.no_cuda and torch.cuda.is_available()) else torch.device('cpu')

    # Station data and distance matrix computations
    stations_df = pd.DataFrame.from_dict(stations, orient='index', columns=['Latitude', 'Longitude'])

    coords = stations_df.to_numpy()
    distance_matrix = np.zeros((len(coords), len(coords)))

    for i in range(len(coords)):
        for j in range(len(coords)):
            distance_matrix[i, j] = haversine(coords[i][0], coords[i][1], coords[j][0], coords[j][1])
    
    print(sys.version)
    print(platform.node(), platform.platform())
    print(device)

    # Load and preprocess data
    train_df = data.load(years=['2017', '2018', '2019', '2020', '2021'])
    train_dataset = UniDataset(
        train_df, 
        in_days=args.in_days, 
        out_days=args.out_days, 
        device=device, 
        distance_matrix=distance_matrix
    )
    train_loader = DataLoader(train_dataset, batch_size=args.batch_size, shuffle=True)

    val_df = data.load(years=['2022'])
    val_dataset = UniDataset(
        val_df, 
        in_days=args.in_days, 
        out_days=args.out_days, 
        device=device, 
        distance_matrix=distance_matrix
    )
    val_loader = DataLoader(val_dataset, batch_size=args.batch_size, shuffle=True)

    print(f'number of variates: {train_dataset.variates}')

    # Model configuration
    config = AutoformerConfig(
        input_size=train_dataset.variates * 2,  # Original + spatial features
        prediction_length=train_dataset.out_samples,
        context_length=89,
        num_time_features=2,
        d_model=16,
    )

    model = AutoformerForPrediction(config).to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-4)

    for epoch in range(args.epochs):
        loss_avg = train(args, model, device, train_loader, optimizer, epoch)
        print(f'[{epoch+1:02d}/{args.epochs:02d}] {loss_avg:.3f}')
    
    # Save the model and configuration
    torch.save(model.state_dict(), 'multivariate_model.pth')
    model.config.to_json_file('multivariate_config.json')

    val_rmse = eval(args, model, val_loader, epoch)
    print(f'validation rmse: {val_rmse:.3f}')







if __name__ == '__main__':
    if 'ipykernel_launcher' in sys.argv[0]:
        # Default values for Jupyter Notebook
        args = argparse.Namespace(
            batch_size=32,
            batches_per_epoch=100,
            batches_per_val=8,
            epochs=10,
            in_days=4,
            out_days=14,
            no_cuda=False
        )
    else:
        # Parse arguments from the command line
        args = parse_args()
    main(args)
# Out:
# 3.12.6 (v3.12.6:a4a2d2b0d85, Sep  6 2024, 16:08:03) [Clang 13.0.0 (clang-1300.0.29.30)]
# Admins-MacBook-Air.local macOS-14.5-arm64-arm-64bit
# cpu
# Downloading data...
# 100%|██████████| 5/5 [00:00<00:00, 11466.11it/s]
# Downloading data...
# 100%|██████████| 1/1 [00:00<00:00, 9619.96it/s]
# number of variates: 83
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[40], line 100
#      97 else:
#      98     # Parse arguments from the command line
#      99     args = parse_args()
# --> 100 main(args)
#
# Cell In[40], line 69, in main(args)
#      66 optimizer = optim.Adam(model.parameters(), lr=1e-4)
#      68 for epoch in range(args.epochs):
# ---> 69     loss_avg = train(args, model, device, train_loader, optimizer, epoch)
#      70     print(f'[{epoch+1:02d}/{args.epochs:02d}] {loss_avg:.3f}')
#      72 # Save the model and configuration
#
# Cell In[37], line 8, in train(args, model, device, train_loader, optimizer, epoch)
#       5 for batch_idx, (data, data_time, data_mask, target, target_time) in tqdm(enumerate(train_loader), leave=False, total=args.batches_per_epoch) :
#       6     optimizer.zero_grad()
# ----> 8     outputs = model(
#       9         past_values=data,
#      10         past_time_features=data_time,
#      11         past_observed_mask=data_mask,
#      12         future_values=target,
#      13         future_time_features=target_time
#      14     )
#      15     loss = outputs.loss
#      16     loss.backward()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/models/autoformer/modeling_autoformer.py:1918, in AutoformerForPrediction.forward(self, past_values, past_time_features, past_observed_mask, static_categorical_features, static_real_features, future_values, future_time_features, future_observed_mask, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, output_hidden_states, output_attentions, use_cache, return_dict)
#    1915 if future_values is not None:
#    1916     use_cache = False
# -> 1918 outputs = self.model(
#    1919     past_values=past_values,
#    1920     past_time_features=past_time_features,
#    1921     past_observed_mask=past_observed_mask,
#    1922     static_categorical_features=static_categorical_features,
#    1923     static_real_features=static_real_features,
#    1924     future_values=future_values,
#    1925     future_time_features=future_time_features,
#    1926     decoder_attention_mask=decoder_attention_mask,
#    1927     head_mask=head_mask,
#    1928     decoder_head_mask=decoder_head_mask,
#    1929     cross_attn_head_mask=cross_attn_head_mask,
#    1930     encoder_outputs=encoder_outputs,
#    1931     past_key_values=past_key_values,
#    1932     output_hidden_states=output_hidden_states,
#    1933     output_attentions=output_attentions,
#    1934     use_cache=use_cache,
#    1935     return_dict=return_dict,
#    1936 )
#    1938 prediction_loss = None
#    1939 params = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/models/autoformer/modeling_autoformer.py:1660, in AutoformerModel.forward(self, past_values, past_time_features, past_observed_mask, static_categorical_features, static_real_features, future_values, future_time_features, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, output_hidden_states, output_attentions, use_cache, return_dict)
#    1657 use_cache = use_cache if use_cache is not None else self.config.use_cache
#    1658 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1660 transformer_inputs, temporal_features, loc, scale, static_feat = self.create_network_inputs(
#    1661     past_values=past_values,
#    1662     past_time_features=past_time_features,
#    1663     past_observed_mask=past_observed_mask,
#    1664     static_categorical_features=static_categorical_features,
#    1665     static_real_features=static_real_features,
#    1666     future_values=future_values,
#    1667     future_time_features=future_time_features,
#    1668 )
#    1670 if encoder_outputs is None:
#    1671     enc_input = torch.cat(
#    1672         (
#    1673             transformer_inputs[:, : self.config.context_length, ...],
#    (...)
#    1676         dim=-1,
#    1677     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/models/autoformer/modeling_autoformer.py:1556, in AutoformerModel.create_network_inputs(self, past_values, past_time_features, static_categorical_features, static_real_features, past_observed_mask, future_values, future_time_features)
#    1554 context = past_values[:, -self.config.context_length :]
#    1555 observed_context = past_observed_mask[:, -self.config.context_length :]
# -> 1556 _, loc, scale = self.scaler(context, observed_context)
#    1558 inputs = (
#    1559     (torch.cat((past_values, future_values), dim=1) - loc) / scale
#    1560     if future_values is not None
#    1561     else (past_values - loc) / scale
#    1562 )
#    1564 # static features
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/models/autoformer/modeling_autoformer.py:269, in AutoformerMeanScaler.forward(self, data, observed_indicator)
#     255 def forward(
#     256     self, data: torch.Tensor, observed_indicator: torch.Tensor
#     257 ) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
#     258     """
#     259     Parameters:
#     260         data (`torch.Tensor` of shape `(batch_size, sequence_length, num_input_channels)`):
#    (...)
#     267             `(batch_size, 1, num_input_channels)`)
#     268     """
# --> 269     ts_sum = (data * observed_indicator).abs().sum(self.dim, keepdim=True)
#     270     num_observed = observed_indicator.sum(self.dim, keepdim=True)
#     272     scale = ts_sum / torch.clamp(num_observed, min=1)
#
# RuntimeError: The size of tensor a (166) must match the size of tensor b (83) at non-singleton dimension 2

# %%
print("data shape:", data.shape)
print("data_time shape:", data_time.shape)
print("data_mask shape:", data_mask.shape)
print("target shape:", target.shape)
print("target_time shape:", target_time.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 print("data shape:", data.shape)
#       2 print("data_time shape:", data_time.shape)
#       3 print("data_mask shape:", data_mask.shape)
#
# AttributeError: module 'data' has no attribute 'shape'

# %%
class UniDataset(Dataset):
    def __init__(self, df: pd.DataFrame, columns: list = None, in_days=4, out_days=14, 
                 inverse_matrix=None, device='cpu') -> None:
        if columns is None:
            raise ValueError("You must specify the columns corresponding to stations.")

        self.variates = len(columns)
        self.inverse_matrix = (
            torch.tensor(inverse_matrix, dtype=torch.float32, device=device)
            if inverse_matrix is not None else None
        )

        # Validate matrix dimensions
        if self.inverse_matrix is not None:
            if self.inverse_matrix.shape[0] != self.variates:
                raise ValueError(
                    f"Inverse matrix dimensions ({self.inverse_matrix.shape[0]}) do not match "
                    f"the number of selected columns ({self.variates})."
                )

        self.x = torch.tensor(df[columns].values, dtype=torch.float32, device=device)
        self.h = torch.tensor(df['Hour'].values, dtype=torch.float32, device=device) / 24
        self.doy = torch.tensor(df['DayOfYear'].values, dtype=torch.float32, device=device) / 365

        (self.in_samples, self.out_samples) = (24 * in_days, 24 * out_days)
        self.n = len(self.x) - 2 * (self.in_samples + self.out_samples)

    def __len__(self) -> int:
        return self.n

    def __getitem__(self, i: int) -> Tuple[torch.Tensor, torch.Tensor]:
        data = self.x[i:i + self.in_samples]
        data_time = torch.column_stack((
            self.h[i:i + self.in_samples],
            self.doy[i:i + self.in_samples],
        ))
        data_mask = ~data.isnan()
        target = self.x[i + self.in_samples:i + self.in_samples + self.out_samples]
        target_time = torch.column_stack((
            self.h[i + self.in_samples:i + self.in_samples + self.out_samples],
            self.doy[i + self.in_samples:i + self.in_samples + self.out_samples],
        ))

        # Compute spatially weighted data if inverse_matrix is provided
        if self.inverse_matrix is not None:
            spatial_data = torch.matmul(self.inverse_matrix, data.T).T  # Weighted sum
            data_with_spatial = torch.cat((data, spatial_data), dim=1)
        else:
            data_with_spatial = data

        return (
            data_with_spatial, data_time, data_mask, target, target_time
        )

# %%
def main(args):
    device = torch.device('cuda') if (not args.no_cuda and torch.cuda.is_available()) else torch.device('cpu')

    print(sys.version)
    print(platform.node(), platform.platform())
    print(device)

    # Load distance matrix and compute inverse
    # distance_matrix = np.load('distance_matrix.npy')  # Replace with your path
    # epsilon = 1e-6
    # inverse_matrix = 1 / (distance_matrix + epsilon)

    # Load train and validation datasets
    train_df = data.load(years=['2017', '2018', '2019', '2020', '2021'])
    train_dataset = UniDataset(train_df, in_days=args.in_days, out_days=args.out_days, 
                               inverse_matrix=inverse_matrix, device=device)
    train_loader = DataLoader(train_dataset, batch_size=args.batch_size, shuffle=True)

    val_df = data.load(years=['2022'])
    val_dataset = UniDataset(val_df, in_days=args.in_days, out_days=args.out_days, 
                             inverse_matrix=inverse_matrix, device=device)
    val_loader = DataLoader(val_dataset, batch_size=args.batch_size, shuffle=True)

    print(f'number of variates: {train_dataset.variates}')
    
    # Adjust input size to include spatial features
    config = AutoformerConfig(
        input_size=train_dataset.variates * 2,
        prediction_length=train_dataset.out_samples,
        context_length=89,
        num_time_features=2,
        d_model=16,
    )
    model = AutoformerForPrediction(config).to(device)

    optimizer = optim.Adam(model.parameters(), lr=1e-4)

    for epoch in range(args.epochs):
        loss_avg = train(args, model, device, train_loader, optimizer, epoch)
        print(f'[{epoch+1:02d}/{args.epochs:02d}] {loss_avg:.3f}')

    torch.save(model.state_dict(), 'multivariate_model_with_spatial.pth')
    model.config.to_json_file('multivariate_config_with_spatial.json')

    val_rmse = eval(args, model, val_loader, epoch)
    print(f'validation rmse: {val_rmse:.3f}')
    
    return val_loader, model

# %%
columns = [f"Station_{i}" for i in range(83)]  # Replace with actual station names in your dataset
print(f"Inverse matrix shape: {inverse_matrix.shape}")
print(f"Selected columns count: {len(columns)}")
# Out:
# Inverse matrix shape: (83, 83)
# Selected columns count: 83

# %%
columns = [f"Station_{i}" for i in range(83)]  # Ensure these are valid station names


train_dataset = UniDataset(train_df, columns=columns, in_days=4, out_days=14, 
                           inverse_matrix=inverse_matrix, device="cuda")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 4
#       1 columns = [f"Station_{i}" for i in range(83)]  # Ensure these are valid station names
# ----> 4 train_dataset = UniDataset(train_df, columns=columns, in_days=4, out_days=14,
#       5                            inverse_matrix=inverse_matrix, device="cuda")
#
# NameError: name 'train_df' is not defined

# %%
args = parse_args()
val_loader, model = main(args)
# Out:
# 3.12.6 (v3.12.6:a4a2d2b0d85, Sep  6 2024, 16:08:03) [Clang 13.0.0 (clang-1300.0.29.30)]
# Admins-Air.home macOS-14.5-arm64-arm-64bit
# cpu
# Downloading data...
# 100%|██████████| 5/5 [00:00<00:00, 31022.96it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 args = parse_args()
# ----> 2 val_loader, model = main(args)
#
# Cell In[39], line 15, in main(args)
#       8 # Load distance matrix and compute inverse
#       9 # distance_matrix = np.load('distance_matrix.npy')  # Replace with your path
#      10 # epsilon = 1e-6
#      11 # inverse_matrix = 1 / (distance_matrix + epsilon)
#      12
#      13 # Load train and validation datasets
#      14 train_df = data.load(years=['2017', '2018', '2019', '2020', '2021'])
# ---> 15 train_dataset = UniDataset(train_df, in_days=args.in_days, out_days=args.out_days,
#      16                            inverse_matrix=inverse_matrix, device=device)
#      17 train_loader = DataLoader(train_dataset, batch_size=args.batch_size, shuffle=True)
#      19 val_df = data.load(years=['2022'])
#
# Cell In[38], line 5, in UniDataset.__init__(self, df, columns, in_days, out_days, inverse_matrix, device)
#       2 def __init__(self, df: pd.DataFrame, columns: list = None, in_days=4, out_days=14,
#       3              inverse_matrix=None, device='cpu') -> None:
#       4     if columns is None:
# ----> 5         raise ValueError("You must specify the columns corresponding to stations.")
#       7     self.variates = len(columns)
#       8     self.inverse_matrix = (
#       9         torch.tensor(inverse_matrix, dtype=torch.float32, device=device)
#      10         if inverse_matrix is not None else None
#      11     )
#
# ValueError: You must specify the columns corresponding to stations.

# %%
for batch_idx, (data, data_time, data_mask, target, target_time) in enumerate(val_loader):
    outputs = model.generate(
        past_values=data,
        past_time_features=data_time,
        past_observed_mask=data_mask,
        future_time_features=target_time
    )

    pred = outputs.sequences.mean(dim=1)
    break

# Plot predictions
n = 5
fig, ax = plt.subplots(n, 1, figsize=(10, 25))

for i in range(n):
    ax[i].plot(data[i, :, 0].cpu(), label='Input')
    ax[i].plot(torch.arange(target.shape[1]) + data.shape[1], target[i, :, 0].cpu(), label='Ground Truth')
    ax[i].plot(torch.arange(target.shape[1]) + data.shape[1], pred[i, :, 0].cpu(), label='Prediction')
    ax[i].legend()
    ax[i].set_title(f'Sample {i + 1}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 for batch_idx, (data, data_time, data_mask, target, target_time) in enumerate(val_loader):
#       2     outputs = model.generate(
#       3         past_values=data,
#       4         past_time_features=data_time,
#       5         past_observed_mask=data_mask,
#       6         future_time_features=target_time
#       7     )
#       9     pred = outputs.sequences.mean(dim=1)
#
# NameError: name 'val_loader' is not defined

# %%
class AutoformerForPrediction(nn.Module):
    def __init__(self, config: AutoformerConfig):
        super().__init__()
        self.time_embedding = nn.Linear(config.num_time_features, config.d_model)
        self.spatial_embedding = nn.Linear(config.num_spatial_features, config.d_model)  # Add spatial embedding
        # Existing model components

    def forward(self, past_values, past_time_features, past_observed_mask, future_values, future_time_features, spatial_features):
        # Embed time and spatial features
        time_embed = self.time_embedding(past_time_features)
        spatial_embed = self.spatial_embedding(spatial_features)
        
        # Combine features
        combined_features = time_embed + spatial_embed
        # Existing model logic using combined_features

# %%
class UniDataset(Dataset):
    def __init__(self, df: pd.DataFrame, spatial_matrix: pd.DataFrame, columns: str = None, in_days=4, out_days=14, device='cpu') -> None:
        if columns is None:
            columns = [col for col in df.columns if col.startswith('NL')][:25]

        self.variates = len(columns)
        self.spatial_matrix = torch.tensor(spatial_matrix.values, dtype=torch.float32, device=device)

        self.x = torch.tensor(df[columns].values, dtype=torch.float32, device=device)
        self.h = torch.tensor(df['Hour'].values, dtype=torch.float32, device=device) / 24
        self.doy = torch.tensor(df['DayOfYear'].values, dtype=torch.float32, device=device) / 365

        (self.in_samples, self.out_samples) = (24 * in_days, 24 * out_days)
        self.n = len(self.x) - 2 * (self.in_samples + self.out_samples)

    def __len__(self) -> int:
        return self.n

    def __getitem__(self, i: int) -> Tuple[torch.Tensor, torch.Tensor]:
        data = self.x[i:i + self.in_samples]
        data_time = torch.column_stack((
            self.h[i:i + self.in_samples],
            self.doy[i:i + self.in_samples],
        ))
        data_mask = ~data.isnan()
        target = self.x[i + self.in_samples:i + self.in_samples + self.out_samples]
        target_time = torch.column_stack((
            self.h[i + self.in_samples:i + self.in_samples + self.out_samples],
            self.doy[i + self.in_samples:i + self.in_samples + self.out_samples],
        ))

        # Use spatial matrix as a feature for the input data
        spatial_features = self.spatial_matrix

        return (
            data, data_time, data_mask, target, target_time, spatial_features
        )

# %%
def train(args, model, device, train_loader, optimizer, epoch) :
    model.train()

    loss_avg = 0
    for batch_idx, (data, data_time, data_mask, target, target_time) in tqdm(enumerate(train_loader), leave=False, total=args.batches_per_epoch) :
        optimizer.zero_grad()

        outputs = model(
        past_values=data,
        past_time_features=data_time,
        past_observed_mask=data_mask,
        future_values=target,
        future_time_features=target_time,
        spatial_features=spatial_features
        )

        loss = outputs.loss
        loss.backward()
        optimizer.step()

        loss_avg += (loss.item()/args.batches_per_epoch)
        if (batch_idx >= args.batches_per_epoch) : break
    
    return loss_avg

# %%
def eval(args, model, val_loader, epoch):
    model.eval()
    with torch.no_grad():
        rmse = 0
        for batch_idx, (data, data_time, data_mask, target, target_time) in tqdm(enumerate(val_loader), leave=False, total=args.batches_per_val) :
            outputs = model.generate(
                past_values=data,
                past_time_features=data_time,
                past_observed_mask=data_mask,
                future_time_features=target_time
            )

            pred = outputs.sequences.mean(dim=1)
            rmse += (target - pred).square().mean().sqrt() / args.batches_per_val
            if (batch_idx >= args.batches_per_val) : break

    return rmse.item()

# %%
def parse_args() -> argparse.Namespace :
    parser = argparse.ArgumentParser(description='Univariate Autoformer')
    parser.add_argument('--batch-size', type=int, default=32)
    parser.add_argument('--batches-per-epoch', type=int, default=100)
    parser.add_argument('--batches-per-val', type=int, default=8)
    parser.add_argument('--epochs', type=int, default=10)

    parser.add_argument('--in-days', type=int, default=4)
    parser.add_argument('--out-days', type=int, default=14)
    
    parser.add_argument('--no-cuda', action='store_true', default=False)

    return parser.parse_args()

# %%
def main(args) :
    device = torch.device('cuda') if (not(args.no_cuda) and torch.cuda.is_available()) else torch.device('cpu')
    
    print(sys.version)
    print(platform.node(), platform.platform())
    print(device)

    train_df = data.load(years=['2017', '2018', '2019', '2020', '2021'])
    train_dataset = UniDataset(train_df, in_days=args.in_days, out_days=args.out_days, device=device)
    train_loader = DataLoader(train_dataset, batch_size=args.batch_size, shuffle=True)

    val_df = data.load(years=['2022'])
    val_dataset = UniDataset(val_df, in_days=args.in_days, out_days=args.out_days, device=device)
    val_loader = DataLoader(val_dataset, batch_size=args.batch_size, shuffle=True)

    print(f'number of variates: {train_dataset.variates}')
    # TODO : setup the config
    config = AutoformerConfig(
    input_size=train_dataset.variates,
    prediction_length=train_dataset.out_samples,
    context_length=89,
    num_time_features=2,
    num_spatial_features=spatial_matrix.shape[1],  # Add this
    d_model=16,
    )

    model = AutoformerForPrediction(config).to(device)
    
    optimizer = optim.Adam(model.parameters(), lr=1e-4)

    for epoch in range(args.epochs):
        loss_avg = train(args, model, device, train_loader, optimizer, epoch)
        print(f'[{epoch+1:02d}/{args.epochs:02d}] {loss_avg:.3f}')
    
    torch.save(model.state_dict(), 'multivariate_model.pth')
    model.config.to_json_file('multivariate_config.json')

    val_rmse = eval(args, model, val_loader, epoch)
    print(f'validation rmse: {val_rmse:.3f}')

# %%
import sys
if __name__ == "__main__":
    # Filter out Jupyter-related arguments
    sys.argv = [sys.argv[0]] + [arg for arg in sys.argv[1:] if not arg.startswith("--f=")]
    args = parse_args()
